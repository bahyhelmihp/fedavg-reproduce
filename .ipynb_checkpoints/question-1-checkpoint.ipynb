# %%
import json
import pickle
import os

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

from glob import glob

pd.options.mode.chained_assignment = None
sns.set_style("darkgrid")

# %%
#### Settings
### Learning Rate for 2NN = 0.1, no learning rate decay

# %%
os.chdir("/home/bahy/research/icl-prelab-assignment/")

# %%
# !pwd
# Out:
# /home/bahy/research/icl-prelab-assignment

# %%
datas = []
for file_name in glob("logs_q1/*.txt"):
    print(file_name)
    file = open(file_name, "rb")
    for data in file.readlines():
        if len(data) < 10: # Ignoring blank space/not useful information
            continue
        dict_data = eval(data)
        dict_data['setting'] = file_name.split("/")[1].split("-")[0]
        dict_data['model'] = file_name.split("/")[1].split("-")[-1].split(".")[0]
        datas.append(dict_data)
        
datas = pd.DataFrame(datas)
# Out:
# logs_q1/IID-B10-E1-C0.1-MNIST-2NN.txt
# logs_q1/NONIID-B10-E1-C0.1-MNIST-2NN.txt

# %%
# Sort the data
ROUNDING_DIGIT = 4

df_metrics = datas.sort_values(by=['setting', 'B', 'C', 'comm_round']).reset_index(drop=True)
df_metrics['E'] = 1
df_metrics['train_acc'] = df_metrics['train_acc'].apply(lambda x: round(x, ROUNDING_DIGIT))
df_metrics['test_acc'] = df_metrics['test_acc'].apply(lambda x: round(x, ROUNDING_DIGIT))
df_metrics['train_loss'] = df_metrics['train_loss'].apply(lambda x: round(x, ROUNDING_DIGIT))
df_metrics['test_loss'] = df_metrics['test_loss'].apply(lambda x: round(x, ROUNDING_DIGIT))
df_metrics.head()
# Out:
#      C   B  learning_rate  comm_round  train_acc  test_acc  train_loss  \
# 0  0.1  10            0.1           1     0.8304    0.8349      0.7483
# 1  0.1  10            0.1           2     0.8606    0.8651      0.4973
# 2  0.1  10            0.1           3     0.8842    0.8904      0.4091
# 3  0.1  10            0.1           4     0.9013    0.9062      0.3506
# 4  0.1  10            0.1           5     0.9034    0.9086      0.3233
#
#    test_loss  val_acc  val_loss setting model  E
# 0     0.7324   0.8298    0.7466     IID   2NN  1
# 1     0.4816   0.8569    0.4951     IID   2NN  1
# 2     0.3939   0.8824    0.4065     IID   2NN  1
# 3     0.3395   0.9004    0.3457     IID   2NN  1
# 4     0.3090   0.9044    0.3155     IID   2NN  1

# %%
df_metrics.tail()
# Out:
#         C   B  learning_rate  comm_round  train_acc  test_acc  train_loss  \
# 1061  0.1  10            0.1        1004     0.9692    0.9650      0.0947
# 1062  0.1  10            0.1        1005     0.9709    0.9671      0.0876
# 1063  0.1  10            0.1        1006     0.9726    0.9687      0.0822
# 1064  0.1  10            0.1        1007     0.9723    0.9671      0.0844
# 1065  0.1  10            0.1        1008     0.9744    0.9702      0.0782
#
#       test_loss  val_acc  val_loss setting model  E
# 1061     0.1128   0.9652    0.1166  NONIID   2NN  1
# 1062     0.1059   0.9649    0.1123  NONIID   2NN  1
# 1063     0.1020   0.9670    0.1063  NONIID   2NN  1
# 1064     0.1054   0.9677    0.1094  NONIID   2NN  1
# 1065     0.1014   0.9683    0.1051  NONIID   2NN  1

# %%
df_metrics['label'] = df_metrics['setting'].apply(lambda x: str(x)) + " " +\
                        df_metrics['B'].apply(lambda x: "B=" + str(x)) + " " +\
                        df_metrics['C'].apply(lambda x: "C=" + str(x)) + " " +\
                        df_metrics['E'].apply(lambda x: "E=" + str(x))
df_metrics.head()
# Out:
#      C   B  learning_rate  comm_round  train_acc  test_acc  train_loss  \
# 0  0.1  10            0.1           1     0.8304    0.8349      0.7483
# 1  0.1  10            0.1           2     0.8606    0.8651      0.4973
# 2  0.1  10            0.1           3     0.8842    0.8904      0.4091
# 3  0.1  10            0.1           4     0.9013    0.9062      0.3506
# 4  0.1  10            0.1           5     0.9034    0.9086      0.3233
#
#    test_loss  val_acc  val_loss setting model  E               label
# 0     0.7324   0.8298    0.7466     IID   2NN  1  IID B=10 C=0.1 E=1
# 1     0.4816   0.8569    0.4951     IID   2NN  1  IID B=10 C=0.1 E=1
# 2     0.3939   0.8824    0.4065     IID   2NN  1  IID B=10 C=0.1 E=1
# 3     0.3395   0.9004    0.3457     IID   2NN  1  IID B=10 C=0.1 E=1
# 4     0.3090   0.9044    0.3155     IID   2NN  1  IID B=10 C=0.1 E=1

# %%
table_df = df_metrics.groupby(["label"]).size().to_frame('comm_round').reset_index()
table_df
# Out:
#                    label  comm_round
# 0     IID B=10 C=0.1 E=1          58
# 1  NONIID B=10 C=0.1 E=1        1008

# %%
df_metrics.groupby(["label"])[['test_acc', 'train_acc', 'val_acc']].max()
# Out:
#                        test_acc  train_acc  val_acc
# label
# IID B=10 C=0.1 E=1       0.9700     0.9769   0.9711
# NONIID B=10 C=0.1 E=1    0.9702     0.9756   0.9683

# %%
def make_monotonic(input_df, metric):
    input_df = input_df.reset_index(drop=True)
    
    if "acc" in metric:
        max_val = input_df[metric][0]
        keep = []

        for i in range(len(input_df)):
            current = input_df[metric][i]
            if max_val <= current:
                keep.append(input_df['comm_round'].index[i])
                max_val = current     
    else:
        min_val = input_df[metric][0]
        keep = []

        for i in range(len(input_df)):
            current = input_df[metric][i]
            if min_val >= current:
                keep.append(input_df['comm_round'].index[i])
                min_val = current
    
    return input_df.iloc[keep].reset_index(drop=True)

def fill_the_gap(input_df, round_to_achieve):
    if len(input_df) == round_to_achieve:
        return input_df
    
    initial_comm = input_df.tail(1)['comm_round'].values[0]
    for i in range(round_to_achieve - initial_comm):
        add_df = input_df.tail(1)
        add_df['comm_round'] = add_df['comm_round'] + 1
        input_df = input_df.append(add_df)
    
    return input_df.reset_index(drop=True)

# %%
for combination in df_metrics['label'].unique():
    styles = ['solid', 'dashed', 'dotted']
    metrics = ["train_acc", "val_acc", "test_acc"]
    for i in range(3):
        style, metric = styles[i], metrics[i]
        sample_df = df_metrics[df_metrics['label'] == combination]
        max_len = len(sample_df)
        sample_df = make_monotonic(sample_df, metric)
        sample_df = fill_the_gap(sample_df, max_len)
    
        sns.lineplot(data=sample_df, x='comm_round', y=metric, label=metric, linestyle=style)

    plt.ylim(0.85, 1)
    plt.title("MNIST 2NN\n%s" % combination)
    plt.ylabel("Accuracy")
    plt.xlabel("Communication Rounds")
    plt.legend(loc='lower right')
    plt.savefig("logs_q1/MNIST 2NN\n%s_accuracy.png" % combination)
    plt.show()
    
for combination in df_metrics['label'].unique():
    styles = ['solid', 'dashed', 'dotted']
    metrics = ["train_loss", "val_loss", "test_loss"]
    for i in range(3):
        style, metric = styles[i], metrics[i]
        sample_df = df_metrics[df_metrics['label'] == combination]
        max_len = len(sample_df)
        sample_df = make_monotonic(sample_df, metric)
        sample_df = fill_the_gap(sample_df, max_len)
    
        sns.lineplot(data=sample_df, x='comm_round', y=metric, label=metric, linestyle=style)

    plt.ylim(None, 0.75)
    plt.title("MNIST 2NN\n%s" % combination)
    plt.ylabel("Loss")
    plt.xlabel("Communication Rounds")
    plt.legend(loc='upper right')
    plt.savefig("logs_q1/MNIST 2NN\n%s_loss.png" % combination)
    plt.show()
